# %%
from IPython.display import IFrame, Image
import matplotlib.pyplot as plt

# %%
Image("../plots/simulated_clf/reconst_loss2000.png")

# %%
Image("../plots/simulated_clf/latent_loss2000.png")

# %%
IFrame("../plots/simulated_clf/reconst_loss.pdf", width=600, height=600)
# Out:
#         <iframe
#             width="600"
#             height="600"
#             src="../plots/simulated_clf/reconst_loss.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
