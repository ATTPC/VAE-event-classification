# %%
from IPython.display import IFrame, Image
import matplotlib.pyplot as plt

# %%
Image("/home/robersol/github/thesis/chapters/results/classification/plots/ac_tsne.png")

# %%
Image("/home/robersol/github/thesis/chapters/results/classification/plots/ac_n_samples.png")

# %%
Image("/home/robersol/github/thesis/chapters/results/classification/plots/vgg_ac_n_samples.png")

# %%
Image("../plots/convae_simulated_clf/reconst_loss2000.png")

# %%
Image("../plots/convae_simulated_clf/latent_loss2000.png")

# %%
Image("../plots/convae_simulated_clf/n_labelled_perf.png")

# %%
IFrame("../plots/simulated_clf/reconst_loss.pdf", width=600, height=600)
# Out:
#         <iframe
#             width="600"
#             height="600"
#             src="../plots/simulated_clf/reconst_loss.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
