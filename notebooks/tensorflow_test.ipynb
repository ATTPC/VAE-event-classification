# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
canvasses = np.load("./../drawing/canvasses.npy")

# %%
T = canvasses.shape[0]

# %%
print(canvasses.shape)
# Out:
# (10, 100, 16384)

# %%
rows = 10

fig, axs = plt.subplots(nrows=rows, ncols = T, figsize = (30, 20),)
which = np.random.randint(0, 100, size=(rows,))


for i in range(T):
    for j, w in enumerate(which):
        canvass = canvasses[i][w].reshape((128, 128))
        axs[j, i].imshow(canvass)
        
plt.tight_layout()
plt.savefig("drawing_sequence.png")

# %%
data = np.load("./../data/processed/train.npy")
print(data.shape)
# Out:
# (2151, 128, 128, 1)

# %%
plt.imshow(data[0].reshape((128, 128)))
